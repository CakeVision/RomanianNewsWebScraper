# %%
from time import process_time_ns

import pandas as pd

# %%
things = pd.read_json("selenium_news_results.json")

# %%
things.sort_values(by=['date'], ascending=True, inplace=True)

# %%
things.head(10)
# Out:
#                                                title  \
# 0  CEZ Vânzare a devenit Premier Energy Furnizare...
# 1  Grupul CEZ și-a schimbat denumirea în România....
# 2  Premier Energy preia CEZ Vânzare. Ce trebuie s...
# 3  Tentativă de fraudă prin SMS în numele unui fu...
# 4  Un furnizor de energie permite doar plata cu c...
# 5  Peste 2.000 de blocuri fără apă și căldură din...
# 6  Peste 1.000 de blocuri din Capitală vor rămâne...
# 7  Sute de blocuri din trei sectoare ale Capitale...
# 8  De ce încă sunt reci caloriferele din Capitală...
# 9  Studenții de la căminele din Regie vor primi a...
#
#                                                  url          date    source
# 0  https://adevarul.ro/economie/cez-vanzare-a-dev...  16 apr. 2024  adevarul
# 1  https://adevarul.ro/economie/grupul-cez-si-a-s...  08 apr. 2024  adevarul
# 2  https://adevarul.ro/economie/premier-energy-pr...  12 feb. 2024  adevarul
# ...

# %%
things.tail(10)
# Out:
#                                                  title  \
# 424  Scandal penal la Complexul Energetic Oltenia, ...
# 583  Șase mituri despre proiectul reactoarelor modu...
# 382  OMV Petrom a cumpărat cea mai mare rețea de în...
# 66   România, țara cu cel mai mare potențial eolian...
# 71   Riscă România o pană generalizată de curent el...
# 241  VIDEO Meg Ryan revine într-o comedie romantică...
# 179  ACUE: Avem nevoie de rețele puternice pentru a...
# 70   Ministerul Energiei semnează contracte de 330 ...
# 318  Povestea tulburătoare a studentului înecat de ...
# 5    Peste 2.000 de blocuri fără apă și căldură din...
#
#                                                    url           date  \
# 424  https://adevarul.ro/stiri-locale/targu-jiu/sca...   31 ian. 2024
# 583  https://adevarul.ro/economie/sase-mituri-despr...    31 mai 2023
# 382  https://adevarul.ro/economie/omv-petrom-a-cump...    31 mai 2024
# 66   https://adevarul.ro/economie/romania-tara-cu-c...  31 mart. 2024
# ...

# %%
print(things["title"][0])
# Out:
# CEZ Vânzare a devenit Premier Energy Furnizare. Ce trebuie să știe clienții

# %%
texts = pd.read_csv("texts.csv")

# %%
texts.tail(10)
# Out:
#    https://adevarul.ro/economie/cez-vanzare-a-devenit-premier-energy-furnizare-ce-2354867.html  \
# 89  https://adevarul.ro/economie/sute-de-cazuri-de...
# 90  https://adevarul.ro/economie/sase-firme-de-dis...
# 91  https://adevarul.ro/stiri-locale/alba-iulia/al...
# 92  https://adevarul.ro/economie/deer-demareaza-un...
# 93  https://adevarul.ro/stiri-interne/evenimente/a...
# 94  https://adevarul.ro/economie/ancheta-pe-piata-...
# 95  https://adevarul.ro/stiri-locale/bucuresti/pes...
# 96  https://adevarul.ro/stiri-locale/bucuresti/con...
# 97  https://adevarul.ro/stiri-locale/bucuresti/tra...
# 98  https://adevarul.ro/stiri-locale/bucuresti/pes...
#
# ...

# %%
for text in texts["text"]:
